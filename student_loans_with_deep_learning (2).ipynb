# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
print(y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop('credit_ranking', axis=1)

# Review the features DataFrame
display(X.head())
print("\nFeatures info:")
display(X.info())
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.describe()
# Out:
#        payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# count      1199.000000         1199.000000        1199.000000  1199.000000
# mean          8.316847            0.531560           0.268182     2.528565
# std           1.791149            0.179228           0.198520     1.329996
# min           4.600000            0.120000           0.000000     0.900000
# 25%           7.100000            0.400000           0.090000     1.900000
# 50%           7.900000            0.520000           0.250000     2.200000
# 75%           9.200000            0.640000           0.430000     2.600000
# max          15.900000            1.580000           1.000000    13.900000
#
#        alumni_success  study_major_code  time_to_completion  \
# count     1199.000000       1199.000000         1199.000000
# mean         0.087249         15.690158           45.772310
# std          0.046479         10.338537           32.406438
# ...

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_train_scaled = scaler.fit_transform(X_train)

# Fit the scaler to the features training dataset
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the number of inputs (features) to the model
input_features = X_train_scaled.shape[1]

# Review the number of features
display(input_features)
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
nodes_hidden_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
nodes_hidden_layer2 = 3

# Define the number of neurons in the output layer
output_neurons = 1

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(
    tf.keras.layers.Dense(units=nodes_hidden_layer1, activation="relu", input_dim=input_features)
)

# Add the second hidden layer
nn_model.add(
    tf.keras.layers.Dense(units=nodes_hidden_layer2, activation="relu", input_dim=input_features)
)

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(
    tf.keras.layers.Dense(units=output_neurons, activation="sigmoid")
)

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 3)                 21
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 3ms/step - loss: 0.7500 - accuracy: 0.5571
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5755
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6591 - accuracy: 0.6138
# Epoch 4/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6385 - accuracy: 0.6606
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6231 - accuracy: 0.6781
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 0.6881
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6016 - accuracy: 0.6997
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.7014
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5840 - accuracy: 0.7081
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.5274 - accuracy: 0.7375 - 65ms/epoch - 5ms/step
# Loss: 0.5273757576942444, Accuracy: 0.737500011920929

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
nn_model_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model_imported.predict(X_test_scaled)

# Display a sample of the predictions
print(predictions[0:5])
# Out:
# 13/13 [==============================] - 0s 2ms/step
# [[0.2233985 ]
#  [0.28663975]
#  [0.6843205 ]
#  [0.6395212 ]
#  [0.9933001 ]]

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(predictions)
predictions_df["predictions"] = round(predictions_df[0])
display(predictions_df)
# Out:
#             0  predictions
# 0    0.223399          0.0
# 1    0.286640          0.0
# 2    0.684321          1.0
# 3    0.639521          1.0
# 4    0.993300          1.0
# ..        ...          ...
# 395  0.643239          1.0
# 396  0.351178          0.0
# 397  0.897210          1.0
# 398  0.126754          0.0
# 399  0.769543          1.0
#
# [400 rows x 2 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
y_true = [0, 1, 1]
y_pred = [1, 1, 1]
target_names = ['0', '1']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. The type of data to be collected for the student loan recommendation system would have to be their demographic information and academic details. This type of essential data is relevant since age and regional differences could affect the outcome of loan eligibility/terms. Younger students, in this instance, would have completely different payment options compared to those who have extensive life experience. Moreover, the location of the student in question could factor from in-state vs. out-of-state tuition, depending on the programs being offered that would match the financial need required. Additionally, their education levels and fields of study would vary between undergraduate, graduate, and post-graduate studies. For example, graduate students may have access to higher loan limits compared to their undergraduate counterparts. Some fields may even offer additional grants or scholarships that match the expected earnings for manageable income vs. debt levels. Public vs. private institutions may also be a factor that could affect the cost differences and affordability of programs, including incoming graduation dates for potential extensions of the loan.  **
#
#
# **2. Based on the data utilized for the student recommendation system, content-based filtering would be the most appropriate methodology approach. Each loan option would be characterized by features such as eligibility criteria with preexisting loan terms and current interest rates. Secondly, the student's profile presented would be created using the original demographic and academic levels mentioned above. Several benefits of this scenario could present the requirements of specific loans and suggestions for incoming students who have no prior history or knowledge of obtaining financial aid. **
#
#
# **3. Two real-world challenges to consider are ethical considerations and policy/economic reform. For the first instance, we present socioeconomic disparities between students from different positions. The system might inadvertently recommend higher-cost loans to students from lower-income backgrounds only if it bases its sole decision on skewed financial data. Secondly, in certain fields where gender disparity exists, the system being developed could exacerbate the issue by recommending different loan options based on gender-corrolated input. Moreover, due to the policy/economic changes that have taken place over time, interest rate fluctuations can rapidly outpace static, outdated recommendations. The policies implemented that promote loan and student forgiveness programs can shift very dramatically, affecting the relevance of the recommendations created. As a consequence, economic downturns in the market affect the viability of future career paths for hardworking students who choose to pursue a higher-caliber option. **
